# %%
import visualize as vis
import matplotlib as plt

# %matplotlib inline

# %% [markdown]
# # Experimental

# %%
vis.visualize_alg(100, 10, 10, 4)

# %%
vis.visualize_alg(1000, 100, 100, 50)

# %%
vis.visualize_alg(1000, 100, 100, 100)

# %%
vis.visualize_alg(1000, 100, 100, 30)
